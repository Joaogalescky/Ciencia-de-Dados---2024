# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaogalescky/Ciencia-de-Dados---2024/blob/main/Pandas_exercicio_enem_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercício

# %%
#Importação da biblioteca Pandas
import pandas as pd

# %% [markdown]
# ## Base dados
#
# **Fonte da base de dados**
#
# Enem 1998
# [Microdados do Exame Nacional do Ensino Médio - Enem](http://www.dados.gov.br/dataset/microdados-do-exame-nacional-do-ensino-medio-enem)
#
# **Documentação da base de dados**
#
# Para entender a base, acesse a descrição dos campos, disponível neste [link](https://docs.google.com/spreadsheets/d/1tKI5o9wBzBh_SaRccHJKwEzqIekqhyze/edit#gid=1105751035).
#
# **Carregamento da base**
#
# Para carregar a base em um DataFrame Pandas, execute:
# Para acessar o arquivo com a base é necessário solicitar acesso ao Google Drive. No caso desta aula, a base de dados está compartilhada entre todos os alunos incluídos na turma do Google Classroom.
#
# **Google Colaboratory**
#
# Para execuções utilizando o ambiente do Google Colab, execute o código abaixo. A primeira vez que for executado, será solicitado um código de acesso. Para obter esse código, basta clicar no link gerado e seguir as instruções.
# ```python
# #Solicita acesso ao Google Drive
# from google.colab import drive
# drive.mount('/drive')
#
# #Carrega a base de dados direto do Google Drive (Executando no Google Colab)
# enem98 = pd.read_csv('/drive/Shared drives/BasesPublicas/Bases/ENEM/1998/MICRODADOS_ENEM_1998.csv', sep=';', encoding='latin1' )
# ```
# **Jupyter**
#
# Para execuções no Jupyter:
# ```python
# #Colocar a base no mesmo diretório em que está executando o arquivo jupyter
# #enem98 = pd.read_csv('./MICRODADOS_ENEM_1998.csv', sep=';', encoding='latin1' )
#
# ```

# %%
# Solicita acesso ao Google Drive
from google.colab import drive
drive.mount('/drive')

# Carrega a base de dados direto do Google Drive (Executando no Google Colab)
enem98 = pd.read_csv('/drive/Shared drives/BasesPublicas/Bases/ENEM/1998/MICRODADOS_ENEM_1998.csv', sep=';', encoding='latin1' )
# Out:
# Mounted at /drive

# %% [markdown]
# **Exercícios**
#
# Sobre a base de dados referente ao ENEM do ano de 1998, responda as questões abaixo utilizando a biblioteca Pandas.

# %% [markdown]
# Sobre a base:
# 1. Quantas linhas existem na base?
# 1. Quantas colunas existem?

# %%
print(f'N. Linhas: {len(enem98)}')
print(f'N. Colunas: {len(enem98.columns)}')
# Out:
# N. Linhas: 157221
# N. Colunas: 163

# %% [markdown]
# Obtenha cada informação solicitada a seguir:
# - Quantos alunos foram matriculados?

# %%
len(enem98)
# Out:
# 157221

# %% [markdown]
# - Quantos alunos matricularam-se no ENEM por estado?

# %%
enem98['SG_UF_RESIDENCIA'].value_counts()
# Out:
# PR    53722
# RJ    36908
# MG    23412
# PE    10295
# SP     8845
# RN     4492
# ES     3013
# MT     1726
# SC     1313
# MS     1159
# RS      997
# RR      967
# CE      667
# AC      570
# GO      479
# AM      456
# SE      344
# PB      303
# PA      288
# DF      243
# BA      180
# AL      166
# RO      111
# PI      103
# MA       90
# TO       48
# AP       47
# Name: SG_UF_RESIDENCIA, dtype: int64

# %% [markdown]
# - Quantos estudantes matriculados não realizaram a prova?

# %%
enem98['TP_PRESENCA'].dtypes
# Out:
# dtype('int64')

# %%
len(enem98[enem98['TP_PRESENCA'] == 0])
# Out:
# 41646

# %% [markdown]
# - Dos estudantes matriculados, quantos não realizaram a prova, por estado?

# %%
faltantes = enem98[enem98['TP_PRESENCA'] == 0]
faltantes['SG_UF_RESIDENCIA'].value_counts()
# Out:
# RJ    14612
# MG     8733
# PR     6072
# PE     4630
# RN     1908
# SP     1412
# MT      534
# RR      421
# ES      363
# SC      312
# AC      202
# RS      197
# AM      101
# MS       89
# SE       55
# CE       45
# DF       44
# PA       40
# GO       36
# PI       35
# PB       34
# AL       14
# RO       12
# BA       10
# MA       10
# TO        4
# AP        1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %% [markdown]
# - Qual é idade do(a) estudante mais velho(a)?

# %%
enem98['NU_IDADE'].max()
# Out:
# 67.0

# %% [markdown]
# - Quantos estudantes empatam com a idade mais velha?

# %%
print(len(enem98[enem98['NU_IDADE'] == maxIdade]))
enem98[enem98['NU_IDADE'] == maxIdade]
# Out:
# 3
#         NU_INSCRICAO  NU_ANO  NU_IDADE TP_SEXO  CO_MUNICIPIO_RESIDENCIA  \
# 66629          66630    1998      67.0       M                3303500.0
# 84874          84875    1998      67.0       F                3526704.0
# 126892        126893    1998      67.0       F                4104402.0
#
#        NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# 66629              NOVA IGUACU              33.0               RJ
# 84874                     LEME              35.0               SP
# 126892        CANDIDO DE ABREU              41.0               PR
#
#         TP_PRESENCA CO_PROVA  ...  Q128  Q129  Q130  Q131  Q132  Q133 Q134  \
# 66629             1        A  ...     .     .     .     .     .     .    .
# 84874             1        A  ...     B     D     A     A     B     B    A
# 126892            1        B  ...     B     B     B     A     B     C    C
#
#        Q135 Q136  Q137
# 66629     .    .     .
# 84874     A    A     A
# 126892    B    A     C
#
# [3 rows x 163 columns]

# %% [markdown]
# - Os estudantes com a idade mais mais velha são de quais estados?

# %%
enem98[enem98['NU_IDADE'] == maxIdade]['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['RJ', 'SP', 'PR'], dtype=object)

# %% [markdown]
# Qual é a idade do(a) estudante mais novo(a) do Paraná?

# %%
idadeMinPR = enem98[enem98['SG_UF_RESIDENCIA'] == 'PR']['NU_IDADE'].min()
print(idadeMinPR)
# Out:
# 10.0

# %% [markdown]
# - Quantos estudantes possuem a mesma idade do estudante mais novo no Paraná?

# %%
len(enem98[enem98['NU_IDADE'] == idadeMinPR])
# Out:
# 13

# %% [markdown]
# - De quais cidades são os estudantes com a menor idade?

# %%
enem98PR = enem98[enem98['SG_UF_RESIDENCIA'] == 'PR']
enem98PR[enem98PR['NU_IDADE'] == idadeMinPR]
# Out:
#         NU_INSCRICAO  NU_ANO  NU_IDADE TP_SEXO  CO_MUNICIPIO_RESIDENCIA  \
# 120076        120077    1998      10.0       F                4125902.0
# 135626        135627    1998      10.0       F                4118501.0
# 141718        141719    1998      10.0       M                4101200.0
# 148326        148327    1998      10.0       M                4125001.0
#
#        NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# 120076     SAO PEDRO DO PARANA              41.0               PR
# 135626             PATO BRANCO              41.0               PR
# 141718                ANTONINA              41.0               PR
# 148326        SAO JOAO DO IVAI              41.0               PR
#
#         TP_PRESENCA CO_PROVA  ...  Q128  Q129  Q130  Q131  Q132  Q133 Q134  \
# 120076            1        B  ...     A     B     A     A     B     C    C
# 135626            1        Z  ...     A     A     A     B     B     C    C
# 141718            1        B  ...     A     B     A     A     B     C    B
# 148326            1        Z  ...     B     A     A     A     A     A    A
#
#        Q135 Q136  Q137
# 120076    C    A     C
# 135626    B    *     C
# 141718    B    A     C
# 148326    A    B     A
#
# [4 rows x 163 columns]

# %%
enem98PR[enem98PR['NO_MUNICIPIO_RESIDENCIA'] == 'LUIZIANA']
# Out:
#         NU_INSCRICAO  NU_ANO  NU_IDADE TP_SEXO  CO_MUNICIPIO_RESIDENCIA  \
# 95237          95238    1998      24.0       F                4113734.0
# 95249          95250    1998      17.0       M                4113734.0
# 95260          95261    1998      32.0       M                4113734.0
# 95263          95264    1998      26.0       F                4113734.0
# 95264          95265    1998      17.0       M                4113734.0
# ...              ...     ...       ...     ...                      ...
# 107022        107023    1998      19.0       M                4113734.0
# 107025        107026    1998      17.0       F                4113734.0
# 107033        107034    1998      17.0       M                4113734.0
# 107035        107036    1998      23.0       M                4113734.0
# 107130        107131    1998       NaN       M                4113734.0
#
#        NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# 95237                 LUIZIANA              41.0               PR
# 95249                 LUIZIANA              41.0               PR
# 95260                 LUIZIANA              41.0               PR
# 95263                 LUIZIANA              41.0               PR
# 95264                 LUIZIANA              41.0               PR
# ...                        ...               ...              ...
# 107022                LUIZIANA              41.0               PR
# 107025                LUIZIANA              41.0               PR
# 107033                LUIZIANA              41.0               PR
# 107035                LUIZIANA              41.0               PR
# 107130                LUIZIANA              41.0               PR
#
#         TP_PRESENCA CO_PROVA  ...  Q128  Q129  Q130  Q131  Q132  Q133 Q134  \
# 95237             0      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 95249             1        G  ...     B     B     A     A     C     C    B
# 95260             1        A  ...     A     A     A     B     B     C    C
# 95263             1        Z  ...     B     B     A     B     B     C    B
# 95264             1        Z  ...     *     C     A     C     B     C    B
# ...             ...      ...  ...   ...   ...   ...   ...   ...   ...  ...
# 107022            1        B  ...     B     D     D     A     B     C    C
# 107025            1        G  ...     B     B     A     A     C     C    C
# 107033            1        B  ...     B     B     C     A     A     B    A
# 107035            1        A  ...     B     B     A     A     A     C    A
# 107130            1        B  ...     B     C     A     B     B     B    B
#
#        Q135 Q136  Q137
# 95237   NaN  NaN   NaN
# 95249     C    A     C
# 95260     C    A     C
# 95263     B    A     A
# 95264     B    A     B
# ...     ...  ...   ...
# 107022    B    A     B
# 107025    A    A     C
# 107033    A    B     A
# 107035    B    *     B
# 107130    A    B     A
#
# [77 rows x 163 columns]

# %% [markdown]
# - No Paraná, qual a porcentagem de estudantes por sexo?

# %%
enem98PR_Sexo = enem98PR['TP_SEXO'].value_counts()/len(enem98PR)*100
enem98PR_Sexo
# Out:
# F    59.904695
# M    40.095305
# Name: TP_SEXO, dtype: float64
